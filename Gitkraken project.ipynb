# %%
import pandas as pd

# %%
df=pd.read_excel('stock portfolio performance.xlsx')

# %%
df.head()
# Out:
#   Unnamed: 0 the weight of the stock-picking concept   Unnamed: 2  \
# 0         ID                              Large B/P    Large ROE
# 1          1                                       1            0
# 2          2                                       0            1
# 3          3                                       0            0
# 4          4                                       0            0
#
#     Unnamed: 3                               Unnamed: 4            Unnamed: 5  \
# 0   Large S/P    Large Return Rate in the last quarter    Large Market Value
# 1            0                                        0                     0
# 2            0                                        0                     0
# 3            1                                        0                     0
# 4            0                                        1                     0
#
#                Unnamed: 6 the original investment performance indicator  \
# ...
